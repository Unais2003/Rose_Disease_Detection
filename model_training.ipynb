# %%
import kagglehub

path = kagglehub.dataset_download("shuvokumarbasak4004/rose-leaf-disease-dataset")
print("Path to dataset files:", path)

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

train_dir = os.path.join(rose_dir, "train")
val_dir = os.path.join(rose_dir, "validation")
test_dir = os.path.join(rose_dir, "test")



train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)


train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)


model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])


model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])


history = model.fit(train_data, validation_data=val_data, epochs=10)


test_loss, test_accuracy = model.evaluate(test_data)
print("Test Accuracy:", test_accuracy)


model.save("rose_leaf_disease_model.h5")
# Out:
# Path to dataset files: /Users/user/.cache/kagglehub/datasets/shuvokumarbasak4004/rose-leaf-disease-dataset/versions/1
# Found 7350 images belonging to 3 classes.
# Found 7350 images belonging to 3 classes.
# Found 210 images belonging to 3 classes.
# Epoch 1/10
# 230/230 [==============================] - 156s 670ms/step - loss: 0.1222 - accuracy: 0.9518 - val_loss: 0.0010 - val_accuracy: 0.9999
# Epoch 2/10
# 230/230 [==============================] - 151s 657ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 3.9927e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 230/230 [==============================] - 151s 658ms/step - loss: 0.0143 - accuracy: 0.9959 - val_loss: 1.8892e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 230/230 [==============================] - 149s 647ms/step - loss: 2.9283e-04 - accuracy: 0.9999 - val_loss: 3.4725e-07 - val_accuracy: 1.0000
# Epoch 5/10
# ...
